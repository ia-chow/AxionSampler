# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
from matplotlib.ticker import LogFormatterExponent
from tqdm import tqdm
import emcee
import corner
import pymultinest
import json
import getdist
from getdist import plots, MCSamples

# %% [markdown]
# Create the 4-d u-function as mentioned:

# %%
def sigmoid(x, a, b, c, d):
    """
    Returns the sigmoid function f(x) = a/(1 + e^(-(bx - c))) + d 
    
    Parameters are:
    
    a adjusts the minimum and maximum asymptotes of the sigmoidal curve
    b adjusts the steepness of the sigmoidal curve
    c shifts the curve left and right
    d shifts the curve up and down
    
    """
    return a/(1 + np.exp(-(b * x - c))) + d

def neg_exponential(x, a, b, c, d):
    """
    Returns the negative exponential function f(x) = a * e^-bx + c
    
    Parameters are:
    
    a shifts the curve left and right
    b adjusts the steepness of the curve
    c is the horizontal asymptote
    d shifts the curve left and right
    
    """
    return a * np.exp(-b * (x + d)) + c
    

def get_3d_log_likelihood(omega_a, omega_d, m_a, 
                          a_a, b_a, c_a, d_a, 
                          a_d, b_d, c_d, d_d, 
                          a_sa, b_sa, c_sa, d_sa, 
                          a_sd, b_sd, c_sd, d_sd, 
                          a_theta, b_theta, c_theta, d_theta):
    """
    Gets the 3d log likelihood for either de or dm with the given parameters for the means in the 
    omega_a and omega_de/dm direction, the variance in the omega_a direction, and the parameters for the rotation by an angle theta
    """
    
    # x vector
    x = np.array([omega_a, omega_d])  # x = [omega_a, omega_de/dm] vector
    
    # means in the mu_a and mu_de direction
    # sigmoid curves mu_a(m_a) and mu_de(m_a)
    mu_a = sigmoid(m_a, a_a, b_a, c_a, d_a)  # mu_a = mu_a(m_a)
    mu_d = sigmoid(m_a, a_d, b_d, c_d, d_d)  # mu_d = mu_d(m_a) but the sigmoidal curve has different parameters
    # mu is a vector of the two
    mu = np.array([mu_a, mu_d])  # mu = [mu_a, mu_d] vector
    
    # covariance matrix C
    sigma_a = neg_exponential(m_a, a_sa, b_sa, c_sa, d_sa)  # variance in a direction: negative exponential curve, sigma_a = sigma_a(m_a)
    sigma_d = neg_exponential(m_a, a_sd, b_sd, c_sd, d_sd) # variance in de direction: sigmoid curve, sigma_de = sigma_de(m_a)
 
    # rotation
    theta = sigmoid(m_a, a_theta, b_theta, c_theta, d_theta)
    # covariance matrix
    C = np.array(([sigma_a, 0], 
                  [0, sigma_d]))
    # rotation matrix
    rot = np.array(([np.cos(theta), -np.sin(theta)], 
                    [np.sin(theta), np.cos(theta)]))
    
    # return 2d gaussian value, applying the appropriate rotation
    f = np.exp(-((x - mu).T @ np.linalg.inv(rot @ C @ rot.T) @ (x - mu)))  # general expression for a 2D Gaussian

    return f

def get_1d_gaussian(omega_d, m_a, 
                    a_d, b_d, c_d, d_d, 
                    a_sd, b_sd, c_sd, d_sd):
    """
    Gets the 1d gaussian of omega_de or omega_dm evaluated at a given m_a (to multiply with the 3d function)
    """
    # compute 1d gaussian 
    mu_d = sigmoid(m_a, a_d, b_d, c_d, d_d)  # compute mu_d and sigma_d except with the other (de/dm) parameters not used for the 3d likelihood
    sigma_d = neg_exponential(m_a, a_sd, b_sd, c_sd, d_sd)
    # general form of 1d gaussian for a given mu and sigma
    f = np.exp(-((omega_d - mu_d) ** 2)/sigma_d)
    
    return f


def log_likelihood(omega_a, omega_de, omega_dm, m_a):
    # finally, return the log to make it log-likelihood
    return np.log(likelihood(omega_a, omega_de, omega_dm, m_a))

    
def likelihood(omega_a, omega_de, omega_dm, m_a, 
                   a_a_de=0., b_a_de=1.5, c_a_de=6., d_a_de=0., 
                   a_a_dm=0., b_a_dm=1.5, c_a_dm=6., d_a_dm=0.,
                   a_de=0., b_de=1.5, c_de=6., d_de=9.,
                   a_dm=0., b_dm=1.5, c_dm=6., d_dm=9.,
                   a_sa_de=10000., b_sa_de=2., c_sa_de=1.5, d_sa_de=0,
                   a_sa_dm=10000., b_sa_dm=-2, c_sa_dm=1.5, d_sa_dm=-20,
                   a_sde=0., b_sde=0., c_sde=0.2, d_sde=0, 
                   a_sdm=0., b_sdm=0., c_sdm=0.2, d_sdm=0, 
                   a_theta_de=np.pi/4, b_theta_de=1.5, c_theta_de=6., d_theta_de=-np.pi/4, 
                   a_theta_dm=-np.pi/4, b_theta_dm=1.5, c_theta_dm=24., d_theta_dm=0.):

    # omega_a, omega_de, omega_dm, m_a = params  # x is omega_a, y is omega_de, z is omega_dm, w is m_a
    
    # low m_a means that omega_a varies with omega_de and constant with omega_dm
    # this is DE dominates
    if m_a < 10:
        # compute the 3d log likelihood in the omega_a - omega_de plane, using the given parameters
        f_3d = get_3d_log_likelihood(omega_a, omega_de, m_a, 
                                  a_a_de, b_a_de, c_a_de, d_a_de, 
                                  a_de, b_de, c_de, d_de, 
                                  a_sa_de, b_sa_de, c_sa_de, d_sa_de, 
                                  a_sde, b_sde, c_sde, d_sde, 
                                  a_theta_de, b_theta_de, c_theta_de, d_theta_de)
        # compute the 1d gaussian in the omega_a - omega_dm plane, using those parameters
        f_1d = get_1d_gaussian(omega_dm, m_a, 
                               a_dm, b_dm, c_dm, d_dm, 
                               a_sdm, b_sdm, c_sdm, d_sdm)
        
    # high m_a means that omega_a constant with omega_de and varies with omega_dm
    # this is DM dominates
    elif m_a >= 10:
        # compute the 3d log likelihood in the omega_a - omega_dm plane, using the given parameters 
        f_3d = get_3d_log_likelihood(omega_a, omega_dm, m_a, 
                                  a_a_dm, b_a_dm, c_a_dm, d_a_dm, 
                                  a_dm, b_dm, c_dm, d_dm, 
                                  a_sa_dm, b_sa_dm, c_sa_dm, d_sa_dm, 
                                  a_sdm, b_sdm, c_sdm, d_sdm, 
                                  a_theta_dm, b_theta_dm, c_theta_dm, d_theta_dm)
        # compute the 1d gaussian in the omega_a - omega_de plane, using those parameters
        f_1d = get_1d_gaussian(omega_de, m_a, 
                               a_de, b_de, c_de, d_de, a_sde, 
                               b_sde, c_sde, d_sde)
    
    # multiply the gaussian with our original 1d gaussian to get the full likelihood
    # compute the 1d gaussian in the omega_a - omega_de plane, using those param
    return f_3d * f_1d
    
#     f_3d = get_3d_log_likelihood(omega_a, omega_dm, m_a, 
#                           a_a_dm, b_a_dm, c_a_dm, d_a_dm, 
#                           a_dm, b_dm, c_dm, d_dm, 
#                           a_sa_dm, b_sa_dm, c_sa_dm, d_sa_dm, 
#                           a_sdm, b_sdm, c_sdm, d_sdm, 
#                           a_theta_dm, b_theta_dm, c_theta_dm, d_theta_dm)
#     # compute the 1d gaussian in the omega_a - omega_de plane, using those param
#     return f_3d # * f_1d

# %% [markdown]
# Plot all the curves to make sure the function behaviour is working as intended:

# %%
# MEANS
# means in the a axis for the DE and DM functions
a_a_de, b_a_de, c_a_de, d_a_de = 0., 1.5, 6., 0. 
a_a_dm, b_a_dm, c_a_dm, d_a_dm = 0., 1.5, 6., 0.
# means in the de/dm axes for the DE and DM functions
a_de, b_de, c_de, d_de = 0., 1.5, 6., 9. 
a_dm, b_dm, c_dm, d_dm = 0., 1.5, 6., 9.

# VARIANCES
# variances in the a axis for the DE and DM functions
a_sa_de, b_sa_de, c_sa_de, d_sa_de = 10000., 2., 1.5, 0.
a_sa_dm, b_sa_dm, c_sa_dm, d_sa_dm = 10000., -2., 1.5, -20.
# variances in the de/dm axes for the DE and DM functions
a_sde, b_sde, c_sde, d_sde = 0., 0., 0.2, 0.
a_sdm, b_sdm, c_sdm, d_sdm = 0., 0., 0.2, 0.

# ROTATIONS
# rotation angles in the a-de and a-dm planes for the DE and DM functions
a_theta_de, b_theta_de, c_theta_de, d_theta_de = np.pi/4, 1.5, 6., -np.pi/4
a_theta_dm, b_theta_dm, c_theta_dm, d_theta_dm = -np.pi/4, 1.5, 24., 0.

# %% [markdown]
# Plot how the means `mu_a`, `mu_de` and `mu_dm` for the $3$-D DE and DM functions evolve with $m_a$, respectively:
#
# They should appear constant at $\mu_a = 0$ and $\mu_{DE} = \mu_{DM} = 9$.

# %%
# %matplotlib inline
# generate test mas
test_mas = np.linspace(0, 20, int(1e4))
# plot
plt.figure(figsize = (10, 7))
# mu_a for the DE and DM functions
plt.plot(test_mas, sigmoid(test_mas, a_a_de, b_a_de, c_a_de, d_a_de), alpha=1, label = 'mu_a (DE function)')
plt.plot(test_mas, sigmoid(test_mas, a_a_de, b_a_de, c_a_de, d_a_de), alpha=1, label = 'mu_a (DM function)')
# mu_de/mu-dm for the DE and DM functions
plt.plot(test_mas, sigmoid(test_mas, a_de, b_de, c_de, d_de), alpha = 1, label = 'mu_de (DE function)')
plt.plot(test_mas, sigmoid(test_mas, a_dm, b_dm, c_dm, d_dm), alpha = 1, label = 'mu_dm (DM function)')
# legend
plt.legend()

# %% [markdown]
# Plot how the variances `sigma_a`, `sigma_de` and `sigma_dm` for the $3$-D DE and DM functions evolve with $m_a$, respectively:
#
# They should shrink (for the DE plot) or grow (for the DM plot) exponentially along the $a$-axis and be constant along the DE/DM axis.

# %%
# plot
plt.figure(figsize = (10, 7))
# sigma_a for the DE and DM functions
plt.plot(test_mas, neg_exponential(test_mas, a_sa_de, b_sa_de, c_sa_de, d_sa_de), alpha=1, label = 'sigma_a (DE function)')
plt.plot(test_mas, neg_exponential(test_mas, a_sa_dm, b_sa_dm, c_sa_dm, d_sa_dm), alpha=1, label = 'sigma_a (DM function)')
# sigma_de/sigma_dm for the DE and DM functions
plt.plot(test_mas, neg_exponential(test_mas, a_sde, b_sde, c_sde, d_sde), alpha = 1, label = 'sigma_de (DE function)')
plt.plot(test_mas, neg_exponential(test_mas, a_sdm, b_sdm, c_sdm, d_sdm), alpha = 1, label = 'sigma_dm (DM function)')
# legend
plt.yscale('log')
plt.legend()

# %% [markdown]
# Plot how the rotation angles `theta_de` and `theta_dm` for the $3$-D DE and DM functions evolve with $m_a$, respectively:
#
# For the DE plot, it should sigmoidally go from -$\frac{\pi}{4}$ to $0$ for $0 < m_a < 10$ and be constant at $0$ for $10 < m_a < 20$.
#
# For the DM plot, it should be constant at $0$ for $0 < m_a < 10$ and sigmoidally go from $0$ to -$\frac{\pi}{4}$ for $10 < m_a < 20$.

# %%
# plot
plt.figure(figsize = (10, 7))
# theta_de
plt.plot(test_mas, sigmoid(test_mas, a_theta_de, b_theta_de, c_theta_de, d_theta_de), alpha=1, label = 'theta_de')
# theta_dm
plt.plot(test_mas, sigmoid(test_mas, a_theta_dm, b_theta_dm, c_theta_dm, d_theta_dm), alpha=1, label = 'theta_dm')
# legend
plt.legend()

# %% [markdown]
# Compute the function over some $4$-D hypercube:

# %%
npoints = 20  # 20 or so points when I'm testing things

# bounds of our sampling
x_lower, x_upper = 0, 10  # omega_a
y_lower, y_upper = 0, 10  # omega_de
z_lower, z_upper = 0, 10  # omega_dm
w_lower, w_upper = 0, 20  # m_a

X, Y, Z, W = np.meshgrid(np.linspace(x_lower, x_upper, npoints), np.linspace(y_lower, y_upper, npoints), 
                      np.linspace(z_lower, z_upper, npoints), np.linspace(w_lower, w_upper, npoints))

# no multiprocessing

likelihood_arr = np.zeros((npoints, npoints, npoints, npoints))

for i in tqdm(range(0, len(X))):
    for j in range(0, len(Y)):
        for k in range(0, len(Z)):
            for l in range(0, len(W)):
                likelihood_arr[i, j, k, l] = likelihood(X[i, j, k, l], Y[i, j, k, l], Z[i, j, k, l], W[i, j, k, l])
# Out:
# 100%|██████████| 20/20 [00:07<00:00,  2.60it/s]

# %%
from multiprocessing import Pool

npoints = 100 # 20  # 20 or so points when I'm testing things

# bounds of our sampling
x_lower, x_upper = 0, 10  # omega_a
y_lower, y_upper = 0, 10  # omega_de
z_lower, z_upper = 0, 10  # omega_dm
w_lower, w_upper = 0, 20  # m_a

X, Y, Z, W = np.meshgrid(np.linspace(x_lower, x_upper, npoints), np.linspace(y_lower, y_upper, npoints), 
                      np.linspace(z_lower, z_upper, npoints), np.linspace(w_lower, w_upper, npoints))

# # no multiprocessing

# likelihood_arr = np.zeros((npoints, npoints, npoints, npoints))

# for i in tqdm(range(0, len(X))):
#     for j in range(0, len(Y)):
#         for k in range(0, len(Z)):
#             for l in range(0, len(W)):
#                 likelihood_arr[i, j, k, l] = likelihood(X[i, j, k, l], Y[i, j, k, l], Z[i, j, k, l], W[i, j, k, l])

# mutliprocessing
                
# multiprocessing to speed this up:
with Pool() as pool:
    likelihood_arr = pool.starmap(likelihood, tqdm([(X[i, j, k, l], Y[i, j, k, l], Z[i, j, k, l], W[i, j, k, l])
                                                        for i in range(0, len(X)) 
                                                        for j in range(0, len(Y)) 
                                                        for k in range(0, len(Z)) 
                                                        for l in range(0, len(W))]))

# make likelihood_arr into an array with the proper shape
likelihood_arr = np.array(likelihood_arr).reshape(npoints, npoints, npoints, npoints)
# Out:
# 100%|██████████| 100000000/100000000 [28:32<00:00, 58378.00it/s]

# %% [markdown]
# Test to make sure that meshgrid and multiprocessing are doing what I think they are:

# %%
testX, testY, testZ, testW = np.meshgrid(range(0, 4), range(0, 4), range(0, 4), range(0, 4))

def g(x):
    return x

with Pool() as pool:
    test2 = pool.map(g, [f'{i}, {j}, {k}, {l}' 
                  for i in np.linspace(0, 4, 4) 
                  for j in np.linspace(0, 8, 4) 
                  for k in np.linspace(0, 12, 4) 
                  for l in np.linspace(0, 16, 4)])
    
test2 = np.array(test2).reshape(4, 4, 4, 4)

# %% [markdown]
# Hacky fix of swapping the indices of $x$ and $y$ so $(x, y, z, w) \rightarrow (y, x, z, w)$:

# %%
likelihood_arr = likelihood_arr.swapaxes(0, 1)  # swaps the x and y axes in the likelihood array

# %% [markdown]
# Plotting behaviour in the $\Omega_a - \Omega_{DE}$ and $\Omega_a - \Omega_{DM}$ planes:

# %%
# %matplotlib notebook
# %matplotlib notebook

# plotting the omega_a - omega_de plane holding omega_dm constant

import matplotlib.pyplot as plt  
from matplotlib.animation import FuncAnimation
from matplotlib.animation import PillowWriter

# ws
ws = np.linspace(w_lower, w_upper, npoints)
# hold omega_dm constant, vary m_a
omega_dm = 9 * npoints//10  # index of the omega_dm
# zs
zs = np.linspace(z_lower, z_upper, npoints)

plt.rc('font', size=8)
fig, ax = plt.subplots(1, 1, figsize = (4, 3))

def animate(w_ind, omega_dm_ind=omega_dm):
    ax.clear()
    arr = likelihood_arr[:, :, omega_dm_ind, w_ind]  # hold omega_dm constant
    # print(w_ind)
    # min and max for the contours
    contour_min = np.min(arr)
    contour_max = np.max(arr)
    # print(contour_min, contour_max)
    
    # plot
    # need to transpose, I have no idea why?
    ax.contourf(X[:, :, 0, 0].T, Y[:, :, 0, 0].T, arr, levels = np.linspace(contour_min, contour_max, npoints), cmap='viridis')
    ax2 = ax.contour(X[:, :, 0, 0].T, Y[:, :, 0, 0].T, arr, levels = np.linspace(contour_min, contour_max, 5), colors='r')
    ax.clabel(ax2, inline=True, fontsize=6)
    ax.set_xlabel(r'$\Omega_{a}$'), ax.set_ylabel(r'$\Omega_{DE}$') # x is omega_a, y is omega_de, z is m_a
    ax.set_title(fr'$m_a = ${np.round(ws[w_ind], 2)}, $\Omega_{{DM}} = ${np.round(zs[omega_dm], 2)}') # x is omega_a, y is omega_de, z is m_a

fig.set_tight_layout(True)
ani = FuncAnimation(fig, animate, frames=len(Z), interval=1, repeat=False)

# Save the animation as an animated GIF
ani.save("4d_u_function_plot_alternate.gif", dpi=500, writer=PillowWriter(fps=60))
# plt.close()
# Out:
# <div id='1275a1fc-c59f-477c-b98a-4ac273e4bb97'></div>

# %%
# %matplotlib notebook
# %matplotlib notebook

# plotting the omega_a  - omega_dm plane, holding omega_de constant

from matplotlib.animation import FuncAnimation
from matplotlib.animation import PillowWriter

# zs
ws = np.linspace(w_lower, w_upper, npoints)
# hold omega_de constant, vary m_a
omega_de = 9 * npoints//10
# ys (omega_de s)
ys = np.linspace(y_lower, y_upper, npoints)

fig, ax = plt.subplots(1, 1, figsize = (6, 4))

def animate(w_ind, omega_de_ind=omega_de):
    ax.clear()
    arr = likelihood_arr[:, omega_de_ind, :, w_ind].T  # hold omega_de constant her einstead
    # min and max for the contours
    contour_min = np.min(arr)
    contour_max = np.max(arr)
    
    # plot
    ax.contourf(X[:, :, 0, 0], Y[:, :, 0, 0], arr, levels = np.linspace(contour_min, contour_max, npoints), cmap='viridis')
    ax2 = ax.contour(X[:, :, 0, 0], Y[:, :, 0, 0], arr, levels = np.linspace(contour_min, contour_max, 5), colors='r')
    ax.clabel(ax2, inline=True, fontsize=10)
    ax.set_xlabel(r'$\Omega_{a}$'), ax.set_ylabel(r'$\Omega_{DM}$') # x is omega_a, y is omega_de, z is m_a
    ax.set_title(fr'$m_a = ${np.round(ws[w_ind], 2)}, $\Omega_{{DE}} = ${np.round(ys[omega_de], 2)}') # x is omega_a, y is omega_de, z is m_a

ani = FuncAnimation(fig, animate, frames=len(Z), interval=1, repeat=False)

# Save the animation as an animated GIF
ani.save("4d_u_function_plot_de_alternate.gif", dpi=500, writer=PillowWriter(fps=60))
# plt.close()
# Out:
# <div id='49176abc-5e99-46e6-a68f-2ad0bcb7878c'></div>

# %% [markdown]
# Create $4$ panel plot:

# %%
# %matplotlib ipympl

ws = np.linspace(w_lower, w_upper, npoints)
zs = np.linspace(z_lower, z_upper, npoints)

omega_dm_ind = 9 * npoints//10
w_inds = [0, npoints//6, npoints - 1, -1]

fig, ax = plt.subplots(2, 2, figsize = (11, 10))
# plot
for i in range(0, 2):
    for j in range(0, 2):
        w_ind = w_inds[2 * i + j]
        # print(omega_de_ind, w_ind)
        if w_ind != -1:
            arr = likelihood_arr[:, :, omega_dm_ind, w_ind]
            
            contour_min = np.min(arr)
            contour_max = np.max(arr)
            
            ax[i, j].contourf(X[:, :, 0, 0].T, Y[:, :, 0, 0].T, arr, levels = np.linspace(contour_min, contour_max, npoints), cmap='viridis')
            ax2 = ax[i, j].contour(X[:, :, 0, 0].T, Y[:, :, 0, 0].T, arr, levels = np.linspace(contour_min, contour_max, 5), colors='r')
            ax[i, j].clabel(ax2, inline=True, fontsize=10)
            # ax[i, j].contour(X[:, :, 0, 0].T, Y[:, :, 0, 0].T, arr, levels = np.linspace(contour_min, contour_max, 10), colors='r')
            ax[i, j].set_xlabel(r'$\Omega_{a}$')
            ax[i, j].set_ylabel(r'$\Omega_{DE}$') # x is omega_a, y is omega_de, z is m_a
            ax[i, j].set_title(fr'$m_a = ${np.round(ws[w_ind], 2)}, $\Omega_{{DM}}= ${np.round(ys[omega_dm_ind], 2)}') # x is omega_a, y is omega_de, z is m_a
            # ax[i, j].set_title(fr'$m_a = ${np.round(ws[w_ind], 2)}') # x is omega_a, y is omega_de, z is m_a
plt.tight_layout()
plt.savefig('4d_u_function_slices.png')
# Out:
# Warning: Cannot change to a different GUI toolkit: ipympl. Using notebook instead.
# <div id='1cb719d8-92a7-46c9-93bc-7aa56c59d65e'></div>

# %% [markdown]
# Now integrate over $\Omega_{DE}$ from $0$ to $10$ ($-\infty$ to $\infty$ should be the same...) and then $\Omega_{DM}$ from $0$ to $10$:

# %%
from multiprocessing import Pool
import scipy
# x is omega_a, y is omega_de, z is omega_dm, w is m_a

# scipy.integrate.dblquad integrates over the first two arguments by default, so this rearranges it
def f(omega_de, omega_dm, omega_a, m_a):
    return likelihood(omega_a, omega_de, omega_dm, m_a)


# multiprocessing to speed this up:
with Pool() as pool:
    integrated_likelihood = pool.starmap(scipy.integrate.dblquad, tqdm([(f, 0, 10, 0, 10, [X[0, i, 0, j], W[i, 0, 0, j]]) 
                                                                   for i in range(0, len(X)) 
                                                                   for j in range(0, len(W))]))
    
# make integrated likelihood into an array with the proper shape (second element is a numerical error estimate or something)
integrated_likelihood = np.array(integrated_likelihood)[:,0].reshape(npoints, npoints)
# Out:
# 100%|██████████| 10000/10000 [08:09<00:00, 20.41it/s]

# %% [markdown]
# And plot it to see if it matches the u-plot:

# %%
n_contour_points = 500

# min and max for the contours
contour_min = np.min(integrated_likelihood)
contour_max = np.max(integrated_likelihood)

integrated_omega_a, integrated_m_a = X[0, :, 0, :], W[:, 0, 0, :] # these need to be formatted in the right way

# plot
plt.figure(figsize = (12, 8))
plt.contourf(integrated_m_a, integrated_omega_a, integrated_likelihood, levels=np.linspace(contour_min, contour_max, n_contour_points), cmap='viridis')
cb = plt.colorbar()
# cb.formatter = LogFormatterExponent(base=10)
# this goes from ~ -50 to 0
cb.set_ticks(np.linspace(contour_min, contour_max, 20), update_ticks=True)

plt.xlabel(r'$m_a$'), plt.ylabel(r'$\Omega_a$')

# CONTOURS
fig = plt.contour(integrated_m_a, integrated_omega_a, integrated_likelihood, levels=np.linspace(contour_min, contour_max, 20), colors='r')
plt.clabel(fig, inline=True, fontsize=10)
plt.tight_layout()

# save
plt.savefig('integrated_4d_u_function.png', fmt='png')
# Out:
# <div id='0297b2c4-ca5d-40a5-a08e-00e6b193b4f8'></div>

# %% [markdown]
# ## MCMC:

# %% [markdown]
# Define a log prior and a log probability:

# %%
# log prior over the 4-d distribution
def mcmc_log_prior(omega_a, omega_de, omega_dm, m_a, 
                   omega_a_min=x_lower, omega_a_max=x_upper, omega_de_min=y_lower, omega_de_max=y_upper, 
                   omega_dm_min=z_lower, omega_dm_max=z_upper, m_a_min=w_lower, m_a_max=w_upper):
    """
    Log prior that is uniform over x = (0, 10), y = (0, 10), z = (0, 10), w = (0, 20) and 0 outside of that range
    """
    # if they fall within [0, 10], [0, 10], [0, 10], [0, 20], uniform prior, otherwise 0 outside that range
    if (omega_a_min <= omega_a <= omega_a_max and omega_de_min <= omega_de <= omega_de_max 
        and omega_dm_min <= omega_dm <= omega_dm_max and m_a_min <= m_a <= m_a_max):
        return 0.  # log prior, so ln(1) = 0
    else:
        return -np.inf  # log prior, so ln(0) = -infinity
    
# log probability over the 4-d distribution
def mcmc_log_probability(params):
    omega_a, omega_de, omega_dm, m_a = params  # omega_a = x, omega_de = y, omega_dm = z, m_a = w
    # get the log prior for the params
    lp = mcmc_log_prior(omega_a, omega_de, omega_dm, m_a)
    # negative infinity (log(0)) if outside [0, 10], [0, 10], [0, 10], [0, 20] as detected by the log prior
    if not np.isfinite(lp):
        return -np.inf
    # otherwise, log prob is log prior + log likelihood
    return lp + log_likelihood(omega_a, omega_de, omega_dm, m_a)

# %% [markdown]
# Now set up the MCMC (use $50$ walkers with $10^5$ steps) just to check. The starting position of our walkers is drawn from a small Gaussian distribution ($\sigma_i = 0.01$ for $i \in \{1, 2, 3, 4\}$) around the bottom left and bottom right regions of the marginal $2$-D distribution, at the likelihood maxima of $\Omega_{{DE}_{max}} = \Omega_{{DM}_{max}} = 9$

# %%
nwalkers = 50  # nubmer of walkers to use in the MCMC
ndim = 4  # 4 dimensions for our 4-D likelihood function
seed = 0  # seed to use for picking a random point
nsteps = int(1e5)  # number of mcmc steps to take

# choose two starting positions at the bottom left and right corners (w=1 and w=19) 
# and see if the chains are still well-mixed
left_pos = [0.2, 9, 9, 1]  # omega_a = 0.2, omega_de = omega_dm = 9, m_a = 1
right_pos = [0.2, 9, 9, 19]  # omega_a = 0.2, omega_de = omega_dm = 9, m_a = 19
np.random.seed(seed)  # set the seed

left_pos = np.random.multivariate_normal(left_pos, cov = np.diag([0.01, 0.01, 0.01, 0.01], k=0), size=nwalkers//2)
right_pos = np.random.multivariate_normal(right_pos, cov = np.diag([0.01, 0.01, 0.01, 0.01], k=0), size=nwalkers//2)
pos = np.concatenate((left_pos, right_pos))

# setting up the MCMC sampler
filename = '4d_u_function_mcmc_chains.h5'  # this is the binary to save to
backend = emcee.backends.HDFBackend(filename)
backend.reset(nwalkers, ndim)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/h5py/_hl/files.py:185, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     184 try:
# --> 185     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#     186 except IOError:
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:88, in h5py.h5f.open()
#
# OSError: Unable to open file (unable to lock file, errno = 11, error message = 'Resource temporarily unavailable')
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[8], line 19
#      17 filename = '4d_u_function_mcmc_chains.h5'  # this is the binary to save to
#      18 backend = emcee.backends.HDFBackend(filename)
# ---> 19 backend.reset(nwalkers, ndim)
#
# File ~/.local/lib/python3.8/site-packages/emcee/backends/hdf.py:113, in HDFBackend.reset(self, nwalkers, ndim)
#     105 def reset(self, nwalkers, ndim):
#     106     """Clear the state of the chain and empty the backend
#     107
#     108     Args:
#    (...)
#     111
#     112     """
# --> 113     with self.open("a") as f:
#     114         if self.name in f:
#     115             del f[self.name]
#
# File ~/.local/lib/python3.8/site-packages/emcee/backends/hdf.py:97, in HDFBackend.open(self, mode)
#      91 if self.read_only and mode != "r":
#      92     raise RuntimeError(
#      93         "The backend has been loaded in read-only "
#      94         "mode. Set `read_only = False` to make "
#      95         "changes."
#      96     )
# ---> 97 f = h5py.File(self.filename, mode)
#      98 if not self.dtype_set and self.name in f:
#      99     g = f[self.name]
#
# File /usr/lib/python3/dist-packages/h5py/_hl/files.py:406, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, **kwds)
#     404 with phil:
#     405     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 406     fid = make_fid(name, mode, userblock_size,
#     407                    fapl, fcpl=make_fcpl(track_order=track_order),
#     408                    swmr=swmr)
#     410 if isinstance(libver, tuple):
#     411     self._libver = libver
#
# File /usr/lib/python3/dist-packages/h5py/_hl/files.py:187, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     185         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#     186     except IOError:
# --> 187         fid = h5f.create(name, h5f.ACC_EXCL, fapl=fapl, fcpl=fcpl)
#     188 elif mode is None:
#     189     warn("The default file mode will change to 'r' (read-only) in h5py 3.0. "
#     190          "To suppress this warning, pass the mode you need to h5py.File(), "
#     191          "or set the global default h5.get_config().default_file_mode, "
#     192          "or set the environment variable H5PY_DEFAULT_READONLY=1. "
#     193          "Available modes are: 'r', 'r+', 'w', 'w-'/'x', 'a'. "
#     194          "See the docs for details.", H5pyDeprecationWarning, stacklevel=3)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:108, in h5py.h5f.create()
#
# OSError: Unable to create file (unable to open file: name = '4d_u_function_mcmc_chains.h5', errno = 17, error message = 'File exists', flags = 15, o_flags = c2)

# %% [markdown]
# And run the sampler:

# %%
# # running the sampler (w/ parallelization):

# with Pool() as pool:
#     sampler = emcee.EnsembleSampler(nwalkers, ndim, mcmc_log_probability, pool = pool, backend = backend)
#     sampler.run_mcmc(pos, nsteps, progress=True)

# running the sampler (w/out parallelization):

sampler = emcee.EnsembleSampler(nwalkers, ndim, mcmc_log_probability, backend=backend)
sampler.run_mcmc(pos, nsteps, progress=True)

# Get the chain from the samples

samples = sampler.get_chain()[200:]  # discard the first 200 samples ("burn-in" time for the chains to be well-mixed)
# split into x (omega_a), y (omega_de), z (omega_dm) and w (m_a) samples
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]/home/ian/.local/lib/python3.8/site-packages/emcee/moves/red_blue.py:99: RuntimeWarning: invalid value encountered in double_scalars
#   lnpdiff = f + nlp - state.log_prob[j]
# 100%|██████████| 100000/100000 [09:26<00:00, 176.64it/s]

# %% [markdown]
# Get the samples as a chain and then plot all the 2-D marginalized plots using `corner`:

# %%
import h5py
cluster_data = h5py.File(filename, 'r')  # import data
burnin=200  # discard 200 burn in steps

accepted, samples, log_prob = np.array(cluster_data['mcmc']['accepted'])[burnin:], np.array(cluster_data['mcmc']['chain']), np.array(cluster_data['mcmc']['log_prob'])

# remove burn in
samples = samples[burnin:].reshape(((nsteps-burnin) * nwalkers, ndim))

# %%
omega_a_samples = samples[:, 0]
omega_de_samples = samples[:, 1]
omega_dm_samples = samples[:, 2]
m_a_samples = samples[:, 3]

# %% [markdown]
# Generate the $2$-D marginalized u-distribution ($m_a$ vs. $\Omega_a$) using GetDist and compare to before:

# %%
# %matplotlib notebook

u_plot_samples = MCSamples(samples=samples[:, [3, 0]], names = [r'm_a', r'\Omega_a'], labels = [r'm_a', r'\Omega_a'])                                                                
u_plot_samples.updateSettings({'contours': [0.68, 0.95, 0.99]})

g = plots.get_single_plotter()
g.settings.num_plot_contours = 3
g.settings.axes_fontsize = 18
g.settings.lab_fontsize = 18
g.settings.legend_fontsize = 25
g.plot_2d(u_plot_samples, r'm_a', r'\Omega_a', filled=True, shaded=True)
plt.tight_layout()
plt.savefig('u_plot_mcmc_contours.png')
# Out:
# Removed no burn in
# <div id='8da266c0-199d-455d-871d-d9a123a801d9'></div>
# WARNING:root:fine_bins_2D not large enough for optimal density: m_a, \Omega_a
# <ipython-input-110-02bbe6fa758c>:12: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# Generate all the marginal distributions with `corner.corner`

# %%
# %matplotlib notebook
# %matplotlib notebook
plt.figure(figsize = (12, 8))
corner.corner(samples.reshape(((nsteps-200) * 50, 4)), labels=[r'$\Omega_a$', r'$\Omega_{DE}$', r'$\Omega_{DM}$', r'$m_a$'], levels=[0.68, 0.95, 0.99])
plt.savefig('4d_marginalized_cornerplot_mcmc.png')
# Out:
# <div id='e37a7419-2c8e-4f58-9f6a-13d25c9918b3'></div>
# <div id='12b4406f-051e-47be-a91f-c77951c8684d'></div>

# %% [markdown]
# GetDist contours:

# %%
names = [r'\Omega_a', r'\Omega_{DE}', r'\Omega_{DM}', r'm_a']

# convert the samples into an MCSamples object
mcmc_samples = MCSamples(samples=samples, names=names, labels=names)
mcmc_samples.updateSettings({'contours': [0.68, 0.95, 0.99]})

g = plots.get_subplot_plotter()
g.settings.num_plot_contours = 3
g.settings.axes_fontsize = 18
g.settings.lab_fontsize = 30
g.settings.legend_fontsize = 25

g.triangle_plot([mcsamples_mcmc], names, filled=True, shaded=True)
plt.savefig('4d_marginalized_cornerplot_mcmc_contours.png')
plt.show()


# names = [r"\omega_{\mathrm{b}}", 
#          r"\omega_{\mathrm{cdm}}", 
#          r"h", 
#          r"\tau",
#          r"n_s", 
#          r"ln 10^{10} A_s",
#          #r"log 10^{32} ma",
#          r"\omega_{\mathrm{ax}}",
#          r"A_{planck}"]
# labels = names
# # mcsamples = MCSamples(samples=samples_test, names = names, labels = labels)
# mcsamples_ax = MCSamples(samples=samples_ax,names = names, labels = labels)
# g = plots.get_subplot_plotter()
# g.settings.axes_fontsize = 18
# g.settings.lab_fontsize = 30
# g.settings.legend_fontsize = 25

# ##m = 1e-25 axion
# g.triangle_plot([mcsamples_ax], filled=True, legend_labels=['4e5 emulator+GPU sampler (Planck CMB data; ma=1e-25)'])
# plt.show()
# Out:
# Removed no burn in
# <div id='2114b1c3-d2c9-4ee0-be5e-fb90f5d8466f'></div>
# WARNING:root:auto bandwidth for \Omega_a very small or failed (h=0.000303040638775941,N_eff=4990000.0). Using fallback (h=0.007091490492524311)
# WARNING:root:auto bandwidth for \Omega_{DE} very small or failed (h=0.0004277657982321957,N_eff=4990000.0). Using fallback (h=0.0025304487482713093)
# WARNING:root:auto bandwidth for \Omega_{DM} very small or failed (h=0.00040727933588081717,N_eff=4990000.0). Using fallback (h=0.002568336500480261)
# WARNING:root:auto bandwidth for m_a very small or failed (h=0.0002629456091603814,N_eff=4990000.0). Using fallback (h=0.006172622791636614)
# WARNING:root:fine_bins_2D not large enough for optimal density: \Omega_a, \Omega_{DE}
# WARNING:root:fine_bins_2D not large enough for optimal density: \Omega_a, \Omega_{DM}
# WARNING:root:fine_bins_2D not large enough for optimal density: \Omega_a, m_a
# WARNING:root:fine_bins_2D not large enough for optimal density: \Omega_{DE}, \Omega_{DM}
# WARNING:root:fine_bins_2D not large enough for optimal density: \Omega_{DE}, m_a
# WARNING:root:fine_bins_2D not large enough for optimal density: \Omega_{DM}, m_a

# %% [markdown]
# Plot to see if the chains are well-mixed:

# %%
plt.rc('font', size=20)
_, ax = plt.subplots(4, figsize = (20, 14))
# plot the chains for x
ax[i, j].plot(omega_a_samples, color='k', alpha=0.3)
ax[i, j].set_xlim(0, len(omega_a_samples))
ax[i, j].set_ylabel(r'$\Omega_a$')
# plot the chains for y
ax[1].plot(omega_de_samples, color='k', alpha=0.3)
ax[1].set_xlim(0, len(omega_de_samples))
ax[1].set_ylabel(r'$\Omega_{DE}$')
# plot chains for z
ax[2].plot(omega_dm_samples, color='k', alpha=0.3)
ax[2].set_xlim(0, len(omega_dm_samples))
ax[2].set_ylabel(r'$\Omega_{DM}$')
# plot chains for w
ax[3].plot(m_a_samples, color='k', alpha=0.3)
ax[3].set_xlim(0, len(m_a_samples))
ax[3].set_ylabel(r'$m_a$')
# set shared x label
ax[1].set_xlabel('step number')
ax[3].yaxis.set_label_coords(-0.1, 0.5)
# plt.savefig('u_plot_chains.png', fmt='png')
# Out:
# <div id='2538bd74-67f1-4187-917e-b60a6fb1097f'></div>

# %% [markdown]
# ## Nested sampling:

# %% [markdown]
# Define a nested prior using the same upper and lower bounds used for MCMC:

# %%
# bounds of our sampling
x_lower, x_upper = 0, 10  # omega_a
y_lower, y_upper = 0, 10  # omega_de
z_lower, z_upper = 0, 10  # omega_dm
w_lower, w_upper = 0, 20  # m_a

def nested_prior(cube, 
                 x_min=x_lower, x_max=x_upper, 
                 y_min=y_lower, y_max=y_upper, 
                 z_min=z_lower, z_max=z_upper, 
                 w_min=w_lower, w_max=w_upper):
    """
    Prior that is uniform 1 over x = (0, 10), y = (0, 10), z = (0, 10), w = (0, 20) and 0 outside of that range
    params are x, y
    
    Transforms uniform unit cube to cube defined by x and y above
    """

    # transform uniform unit cube
    cube[0] = cube[0] * (x_max - x_min) + x_min  # transforms [0, 1] unit cube to [x_min, x_max] uniform
    cube[1] = cube[1] * (y_max - y_min) + y_min  # transforms [0, 1] unit cube to [y_min, y_max] uniform
    cube[2] = cube[2] * (z_max - z_min) + z_min  # transforms [0, 1] unit cube to [z_min, z_max] uniform
    cube[3] = cube[3] * (w_max - w_min) + w_min  # transforms [0, 1] unit cube to [w_min, w_max] uniform
    
    return cube

# %% [markdown]
# Set up the nested sampler:

# %%
params = ['omega_a', 'omega_de', 'omega_dm', 'm_a']  # x, y, z, w in that order
n_params = len(params)

# %% [markdown]
# Run PyMultiNest:

# %%
import pymultinest

# figure out how to save this to directory at some point? currently throws an error when i try to do it

prefix = '4d_chains/nested-'

# run the pymultinest, try with 1e5 points first with the same parameters are with the 2d function to see if it works

def g(params):
    # unpack tuple of params
    omega_a, omega_de, omega_dm, m_a = params
    # return log likelihood of those params
    return log_likelihood(omega_a, omega_de, omega_dm, m_a)

result = pymultinest.solve(LogLikelihood=g, Prior=nested_prior, n_dims=n_params, 
                           n_live_points=int(1e5), evidence_tolerance=0.5, outputfiles_basename=prefix, verbose=True)
# pymultinest.run()
# Out:
# <ipython-input-2-701183f66811>:86: RuntimeWarning: divide by zero encountered in log
#   return np.log(likelihood(omega_a, omega_de, omega_dm, m_a))
# WARNING: loglikelihood not finite: -inf
#          for parameters: [2.63866007 0.49507737 0.01143634 5.79903007]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.54630363 0.48178434 0.44240952 7.91667581]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.60532403  0.64235687  0.6539464  10.87102771]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 1.34783864  0.27387321  0.4700017  12.70597696]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 3.24418664  0.40173054  0.20411551 10.70838451]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 1.49704456  0.39201379  0.03932834 14.24182653]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [1.62962079 0.23771167 0.35581708 6.47075176]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 2.08458006  0.30326188  0.18174171 14.27571416]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [4.26938355 0.12272716 0.03151178 5.63042045]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.61461294e+00 2.79591084e-01 1.27446651e-02 1.29659021e+01]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 2.82463729  0.08174479  0.01341581 12.38027096]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 6.8280226   0.03555179  0.9453851  12.16410398]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.83281326  0.25689304  0.12255728 11.11202836]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [0.18289506 0.24670243 0.19696236 7.22938299]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 5.03067136  0.2882874   0.31040192 12.51416445]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 1.56695604  0.39331019  0.33300221 10.44085383]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [5.65144479 0.06164074 0.47463775 6.65119886]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.34483361  0.6656158   0.33470094 13.63689065]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 5.86886883  0.0614351   0.07167816 13.63787174]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.48869979 1.2040019  0.08563936 8.07876587]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 3.45775366  0.09298205  0.54536819 10.75677752]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 5.05963683  0.04324555  0.1153791  11.91887259]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.55160201  0.2430588   0.87098777 13.60004663]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.67377317  0.20979464  0.48519492 14.1656816 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [1.96257234 0.10998011 0.05068958 6.53718472]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.76232231 0.31384468 0.58068633 8.33495736]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.72346544  0.24109185  0.01562476 14.31171179]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [1.7506057  0.02398551 0.52005231 5.88719726]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 4.94678557  0.25008321  0.16032398 12.09836602]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [3.49873483 0.65063953 0.11829138 8.22445631]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 6.47862673  0.31469762  0.40181041 11.81317449]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.25748205  0.51147044  0.48587024 10.05460501]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [2.60081708 0.02385437 0.25244594 8.8440752 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [0.6188798  0.49067557 0.05283773 6.8812263 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [1.2726903  0.27123451 0.27076721 6.36027932]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [3.2585901  0.29919505 0.24914801 9.54930425]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [3.16961706 0.1036793  0.2386409  7.39271879]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.76633084 0.35264611 0.16003251 5.6102097 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.28910732  0.956949    0.4170686  10.76113462]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.31212366e+00 4.58081961e-01 8.16941261e-03 7.64379621e+00]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.96628261 0.36738813 0.10596037 9.60376143]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.72652841 0.05652666 0.6980598  5.92369437]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [1.66538835 0.13970733 0.20166874 7.60063052]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 1.32720292  0.37440419  0.08389711 13.45157266]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.26894498 0.16028762 0.23332834 6.66622877]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.71333206 0.28137624 0.53072155 9.88416076]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 2.11276174  0.36408186  0.29318035 14.10043716]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [4.57240105 0.53183079 0.14937758 9.71266389]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [2.35912502e+00 2.67922878e-03 3.95339727e-01 1.20395470e+01]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.44122851  0.71671128  0.01754344 14.30831671]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.43567264 0.34808576 0.01018465 8.35347176]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.35290647  0.4896009   0.38793385 12.30336308]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [0.40883899 0.09442985 0.01145303 9.62425113]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.33328211 0.09045005 0.72101772 8.76384139]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [3.81128073 0.05484581 0.1346308  9.42472458]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.04869616  0.69514573  0.02727449 13.22020531]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.53179038 0.28363049 0.57332337 6.19966149]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [4.57958162 0.85274458 0.01209319 6.92236781]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [3.72435629 0.40711105 0.14344215 8.30633998]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [5.90621293 0.02413332 0.78991532 7.52017021]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.97532558  0.56212068  0.59231699 11.84672356]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 2.72136331  0.28458297  0.35048306 13.20305228]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.57685697 0.79758883 0.04461229 9.81856108]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.47157514 0.41531026 0.21448314 5.51220775]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 4.41150904  0.19408643  0.62069416 11.43030286]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.94568837  0.21544278  0.15404999 13.6979568 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.29050303 0.29515982 0.03891885 8.85112643]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.10573363  1.03227437  0.13314486 13.7738812 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [2.78674304 0.02699614 0.13386428 6.82316542]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 0.12647808  0.16352236  0.53491652 11.57319307]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 5.85040033  0.57762563  0.27414143 11.3462317 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.09409297 0.23313701 0.29549837 9.720155  ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.49479616  1.12929821  0.1171124  11.43287301]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 2.79401898  0.54504871  0.02407789 11.89210892]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [1.79065228 0.02408683 0.47084808 7.1454823 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.54806602  0.04890978  0.85050762 13.44777107]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 6.78126514  0.73328257  0.28676152 10.38048267]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [3.54809463 0.01031756 0.74188471 6.90847158]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.46964872 0.14342785 0.10585308 5.6172967 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [2.1180141  0.30078173 0.1835674  8.27700377]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.49754667 0.45475006 0.62096477 6.9987452 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 2.63212502  0.07918835  0.23720205 11.89742088]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [0.29341578 0.36940277 0.32254457 8.06905508]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.03752577 0.75420141 0.16738534 7.20155597]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.22805834e+00 2.79009342e-03 8.53052139e-01 9.85307336e+00]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.76656377 0.21563351 0.96588254 7.4493432 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.3558327   0.19174874  1.02966011 10.68391562]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [1.37394488 0.57492614 0.17305315 9.34897304]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [1.96433663 0.0732708  0.43554068 7.5203383 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.15071678  0.25129914  0.85997224 10.72782278]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.27728784  0.70846379  0.23140192 11.59902215]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [4.53572214 0.25485098 0.19409537 9.26536441]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.64849246 0.11333048 0.29769719 9.27678347]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.33896017 0.48674107 0.29728055 6.59038424]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.33411217 0.39600015 0.37774324 5.73128581]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.44897592  0.80275238  0.03541946 13.95543933]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.37786198 0.03482401 0.53216338 8.67340565]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.923172    0.25471151  0.41598618 13.65363121]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.98148298  0.94055951  0.21582007 10.29110551]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.27549875  0.17528057  0.03731847 10.00403762]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.22518706  0.36627591  0.0897342  12.19656825]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 6.89252257  0.39859533  0.04051626 14.4340682 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [2.27782547 0.06939411 0.01926422 9.92486358]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [4.18677926e-01 6.55453801e-01 3.69489193e-03 1.03129804e+01]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.33662069  0.42905629  0.25419176 10.33598065]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [5.17462194 0.08352995 0.30892134 7.02953458]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [4.04941022 0.03321171 0.03938079 8.96819711]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.22339129 0.15257418 0.14167964 9.54369187]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 2.43562341  0.23509026  0.09862125 13.68855834]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.61204827 0.80186665 0.56043684 7.92790771]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.13717008  0.47419608  0.35723329 10.05574942]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.29574883  0.30283749  0.44923663 10.47953129]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [2.78854370e-01 6.08995557e-01 8.81552696e-04 1.37569714e+01]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.95211852  0.03247619  0.55454612 12.98298717]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.74169004 0.29349685 0.45778573 9.87189651]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.38613605  0.38439751  0.12242913 12.83703089]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [4.24306095 0.42788804 0.25201857 6.96534395]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.48111308  0.09657621  0.99802792 13.38871956]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.41065133 0.18330216 1.1547327  7.88765073]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.55137491  0.72461247  0.6286639  11.20082855]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.92993307 0.03736317 0.05322397 8.22933316]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.22116804 0.76351643 0.10840535 7.47313499]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.88691688  0.2434814   0.48110783 10.22404909]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [2.45971322 0.03057599 0.51473558 8.62266541]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.0649823  0.68806708 0.39335072 6.38008714]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.01065469  1.10964596  0.15202641 10.07678628]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [5.23350477 0.41246116 0.50272286 7.57215023]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.48386908  0.17071009  0.74473083 12.43027568]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.77313995 0.58450937 0.46680093 6.96365952]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [2.70994008 0.29050052 0.13611734 5.38460732]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 2.0758146   0.36211789  0.18117309 11.33762002]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.0034802   0.17006516  0.19762099 11.09101415]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.35496402 0.68890214 0.3423661  8.46085429]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.66163254 0.01489699 0.0590378  9.27072763]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 6.23778701  0.32499552  0.08415937 13.49920392]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [4.94527161e+00 9.03201103e-02 6.78956509e-03 1.31649792e+01]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 3.77308428  0.31551242  0.23085117 10.30602455]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.21124101  0.04498303  0.23482203 12.22696781]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.199525   0.46178639 0.13918936 9.32813048]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.48161435  0.27639806  0.67139983 13.79548311]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [3.39377463 0.0103724  0.65560043 9.69222784]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.86264479  0.06352425  0.23924649 14.72927094]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [5.94718814 0.40768385 0.04340291 5.39888859]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.60519147  0.66968024  0.29404223 11.62558198]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.96182013e+00 2.15590000e-03 4.15954590e-01 1.11707067e+01]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 2.55262673  0.14856577  0.17417431 11.34055376]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.58155727  1.15193963  0.06678045 12.94390917]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.06490457 0.98958671 0.10434806 8.36349487]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [0.1955241  0.30502677 0.20397007 7.64594913]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.92497802 1.11030221 0.19118726 9.56045151]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [4.66233015 0.26794612 0.29521108 7.638098  ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 6.65694237  0.14093637  0.67103505 13.17865491]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.3040452  0.36801279 0.59122503 6.67638302]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.58670890e+00 8.78930092e-03 1.16603434e+00 1.26871681e+01]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [5.92572808 0.66911101 0.33484697 9.74866152]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 3.31785321  0.04524529  0.46713769 13.79540682]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.34373975 0.89761555 0.44900358 9.75081325]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.83157313  0.47561705  0.22938848 10.01331568]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.1236074   0.26811957  0.75575531 11.10753298]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 3.52455556  0.04879594  0.30773938 11.33989811]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 5.014413    0.55294752  0.25310516 13.3433497 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [5.74945629 0.39637625 0.44202745 7.77139187]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [2.58791089 0.5810827  0.03543675 7.4475646 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.72155273  1.15304887  0.1468277  10.06058812]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.67162025e+00 1.45761967e-01 1.69456005e-03 1.41912282e+01]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.26284313  0.15781879  1.03872418 11.60235286]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.40737367 0.24756551 0.04433155 6.40685201]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.06037104  0.73456109  0.16891241 12.42537022]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 2.74485469  0.07030368  0.42535961 13.76181483]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [3.04332018 0.47010124 0.13759434 7.36427069]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 0.79206109  0.29638767  0.23459196 14.19069648]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [4.39265013 0.10881007 0.17705441 8.07939529]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [5.41772366 0.01339734 0.0965035  6.91510081]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.03547692 0.08444846 0.62367737 8.44070911]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.75343299 0.90058148 0.08605897 8.08976531]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 4.15792406  0.17706156  0.61851084 11.79772258]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.89733458  0.463292    0.64420938 13.4948504 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.82979774  0.06208062  0.08841276 14.41396832]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.25823939 0.10068357 0.15207231 7.83650756]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.02450001 0.19715011 0.91599464 8.21311474]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 2.07454801  0.27968049  0.18435657 12.15201259]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.29446507 0.19453347 0.56639969 7.67040849]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.21856797 0.11634231 0.45737743 6.72242522]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.57888484 0.5821681  0.11479795 7.93319941]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [2.23681927 0.47329068 0.08327186 5.90777278]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.90162909  0.67104161  0.3391856  11.82952523]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.11275864  0.73226511  0.57549775 11.25980735]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.49367857  0.53741992  0.06604314 14.38092947]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.91805565  0.88455021  0.2681601  12.28282094]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.87016737  1.14580989  0.04354417 13.32779527]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [3.70217264 0.16690612 0.0417614  7.20164061]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [2.0235914  0.13426244 0.55044174 7.60871768]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 3.77946079  0.01899123  0.68577409 13.09754729]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [0.25868773 0.48137784 0.11313736 8.89239311]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 1.97322071  0.23700237  0.14342844 13.45637441]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.81501436  0.20455778  0.51467001 13.13679099]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [5.6325829  0.27485609 0.1910913  9.779073  ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 4.64559495  0.33820212  0.25576234 12.83426881]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 5.43150783  0.20390451  0.67070842 12.32576251]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 0.92505097  0.03241658  0.10480464 10.26767015]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.3681494   0.50661743  0.0567615  10.46922684]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.89235711  1.02263033  0.11875689 10.73295236]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.90392697 0.2538681  0.86049616 8.48703504]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [2.17579424e+00 7.20262527e-03 4.15182710e-01 8.20808053e+00]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.03536892  0.42337298  0.4248786  10.79173326]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.57079887  0.01361728  0.78038871 10.14522314]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.28014874 0.32466829 0.25370002 6.93484068]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.87559855  0.20326853  0.25349915 13.31983089]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.88198757 0.57145238 0.83452046 7.29475856]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.84365082 0.09931624 0.26156127 7.78164029]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 6.60123765  0.453251    0.46060562 13.52535009]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [5.26342213 0.22354186 0.15654087 7.13705063]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.85132742e-01 3.29528451e-01 4.85002995e-03 1.25633085e+01]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.66980159 0.01808226 0.10308266 6.25410795]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.44640613  0.15357494  1.04798198 10.92416883]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.26687753  0.16749382  0.1366055  10.01493335]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.90383458 0.44947267 0.23774326 5.86025   ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.97693169 0.147928   0.16139805 8.8558948 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.63875008  1.13545716  0.07649899 10.93177319]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 3.96779299  0.14096677  0.27525485 12.92349935]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 5.16580641  0.38477421  0.43144703 11.8949008 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 4.14792478  0.10012925  0.05465686 13.9169395 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 4.78994787  0.37740886  0.01550436 11.30998135]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 5.05192101  0.06104052  0.59627175 11.17815495]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.31621349 0.47217965 0.42293489 6.30658746]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 5.850389    0.19150972  0.03871977 10.1812613 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.78373003 0.64788103 0.31424224 7.4599421 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.59438741 0.05420744 1.16312981 9.05129075]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 2.78312683  0.53573787  0.10842323 12.60270357]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [4.32387352e+00 5.08964062e-03 6.10663295e-01 8.83072615e+00]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 0.32520711  0.36298811  0.17331958 15.0236392 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 1.57860875  0.09253621  0.23042023 12.55054712]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.06020737  0.37880838  0.13991416 10.39105773]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.91999984  0.22800624  0.40508986 12.88314581]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [0.78246117 0.2883184  0.26174188 8.99027228]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.40975010e+00 7.69495964e-04 2.56117582e-01 1.00148690e+01]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.32503951  0.21362484  0.25235236 13.528409  ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 2.66909301  0.01833379  0.26973128 14.53378081]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.84604478 0.268206   0.31330705 8.74011636]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.08932328 0.42263389 0.9389776  9.91157532]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 4.93024051  0.48241079  0.18597484 10.61855078]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.07985604 0.34597993 0.40023625 7.95154691]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.96654451  0.62797666  0.73170304 12.91850805]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 1.99334085  0.52116811  0.19646108 13.26444149]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.19784963  0.09441197  1.05699599 10.83560824]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 0.33746958  0.47776043  0.02044261 12.54331589]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [8.71061921 0.58440983 0.36557794 7.50909925]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [4.74457860e+00 6.83248043e-03 5.74706197e-01 1.17370713e+01]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [4.49058175 0.37791371 0.05136251 8.89186502]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.64904189 0.72339952 0.31972945 7.29283571]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.13701534  0.62558711  0.01653731 11.31542563]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.82037127  0.31224251  0.92984736 11.10304713]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 3.89141262  0.43424904  0.40761411 10.36890388]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 0.67421317  0.06629765  0.08834124 12.03038096]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.80722845  0.54349124  0.61144054 13.96000862]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.79265213  0.16044021  0.77089667 10.77607155]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 5.29047966  0.25666475  0.57209909 11.52181029]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.51726186 0.69581151 0.23430824 9.34178829]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 1.72562659  0.24577796  0.0838238  13.56364131]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [5.75984776 0.47954977 0.01564384 8.67924094]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.61639118  0.04004598  0.32475889 14.09335136]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [3.05536151 0.4954493  0.05662858 9.86289263]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [0.55077314 0.24528384 0.16766667 7.47103453]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.7442621   0.15203297  0.1406765  10.56022882]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 3.92751396  0.1656121   0.38801908 11.27868056]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [5.35211086 0.27304828 0.57450116 7.32227087]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [1.00990951 0.11029899 0.35749793 6.31493211]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.43278193 0.13491929 0.42232573 7.84737945]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 1.92415655  0.12382567  0.22422791 12.14522719]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.1524756   0.06961465  1.21043026 12.8609097 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [5.75196028 0.12921393 0.35071611 8.39436054]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.02637458  0.64291596  0.27054846 11.0798645 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.25242138 0.11120617 0.34040451 7.82134533]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [0.12717605 0.31386137 0.31175792 5.11479378]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 3.24788809  0.1711756   0.55810094 12.54229903]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.08479285 0.28594673 0.75504124 7.39281058]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [0.01858592 0.03705025 0.40284455 4.59358931]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 2.90349543  0.56522548  0.05757213 12.38701582]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 6.87892437  0.59162974  0.12388229 13.9349699 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.38700914  0.44472158  0.94356    11.66463256]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.22105324  0.12743235  0.58778226 12.20757127]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 1.14053547  0.63327968  0.04128814 10.336833  ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [6.11610830e+00 9.61661339e-03 9.74351764e-01 1.10943174e+01]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 1.37884378  0.22544086  0.25122762 12.96296   ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.33051288e+00 2.39789486e-03 6.15696907e-01 1.28572035e+01]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [1.46261215 0.1230073  0.27637839 8.17397356]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.09304869 0.3071785  0.52788794 8.78064632]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [3.32753301 0.00931561 0.11860907 7.71402717]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 8.33577633  0.21872997  0.38188159 11.40845895]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 0.35165966  0.29150844  0.24595201 12.3634851 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.72379208 0.31390488 1.09484971 8.14164758]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [5.67070067 0.36465406 0.18794119 7.4456048 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [0.9233588  0.11587262 0.50819099 9.10534978]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 7.13500977  0.18867373  0.13519287 14.62927103]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.42933857 1.23659492 0.0200206  8.2772243 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 0.2506423   0.5576998   0.14991939 11.4672792 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 9.8753792   0.05613029  0.05356193 10.63427687]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [7.51498818 0.044595   0.78076661 6.72669053]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [ 1.07817352  0.42099059  0.12849391 13.5216856 ]
#          returned very low value instead
# WARNING: loglikelihood not finite: -inf
#          for parameters: [9.34663594 0.27795613 0.86040676 8.05282474]
#          returned very low value instead

# %% [markdown]
# Loading the data:

# %%
prefix = '4d_chains/nested-'

post_equal_weights = np.loadtxt(f'{prefix}post_equal_weights.dat')
res = np.loadtxt(f'{prefix}.txt')
# stats = np.loadtxt(f'{prefix}stats.dat')

# %% [markdown]
# Plotting $2$-D histogram ($m_a$ vs $\Omega_a$) of the sampled distribution:

# %%
plt.figure(figsize = (12, 8))
# contours (parameters are omega_a, omega_de, omega_dm, m_a)
corner.hist2d(post_equal_weights[:,3], post_equal_weights[:,0], s=0.1, 
              plot_datapoints=False, plot_density=False, levels=[0.68, 0.95, 0.99], color='r')
# density
plt.hist2d(post_equal_weights[:,3], post_equal_weights[:, 0], norm=LogNorm(), bins=1000)
plt.xlabel(r'$m_a$'), plt.ylabel(r'$\Omega_a$')
cb = plt.colorbar()
plt.show()
plt.savefig('m_a_omega_a_nested.png', fmt='png')
# Out:
# <div id='ac5c108c-13f6-427e-8def-48099f4c32a1'></div>

# %% [markdown]
# Plotting the full $4$-D marginalized cornerplot:

# %%
# %matplotlib notebook
# %matplotlib notebook
plt.figure(figsize = (12, 8))
corner.corner(post_equal_weights[:,:-1], labels=[r'$\Omega_a$', r'$\Omega_{DE}$', r'$\Omega_{DM}$', r'$m_a$'], 
              levels=[0.68, 0.95, 0.99])
plt.savefig('4d_marginalized_cornerplot_nested.png', fmt='png')

# %%
# converting the nested samples into an MCSamples object for plotting with getDist
# post_equal_weights[:, :-1] removes the last column (loglikes)
nested_samples = MCSamples(samples=post_equal_weights[:, :-1], names=[r'\Omega_a', r'\Omega_{DE}', r'\Omega_{DM}', r'm_a'], 
                           labels=[r'\Omega_a', r'\Omega_{DE}', r'\Omega_{DM}', r'm_a'])
# 1, 2, 3 sigma
nested_samples.updateSettings({'contours': [0.68, 0.95, 0.99]})

# plotting using getDist
g2 = plots.get_subplot_plotter()
g2.settings.num_plot_contours = 3
g2.triangle_plot(nested_samples, [r'\Omega_a', r'\Omega_{DE}', r'\Omega_{DM}', r'm_a'], shaded=True)
plt.savefig('4d_marginalized_cornerplot_nested_contours.png', fmt='png')

# %% [markdown]
# ## figure this out later!

# %% [markdown]
# Generate autocorrelation plots:

# %%
from numpy.fft import fft, ifft, fftshift

def autocorrelation(x, dt=1):
    """
    computes the autocorrelation of 1d array [x0, x1, ..., xn]
    
    dt is the sampling time (default 1 since each step is 1)
    """
    n = 2 ** (len(x) - 1).bit_length() # n is the length to pad the FFT to (next highest power of 2 for a given chain's length 
    # compute autocorrelation
    autocorr = ifft(np.conj(fft(x, n=n) * dt) * fft(x, n=n) * 1).real[:len(x)]/(4 * n)
    return autocorr

# %%
_, ax = plt.subplots(2, figsize = (15, 10))
# autocorrelation for x
# all chains
for i in range(0, len(y_samples.T)):
    ax[i, j].plot(autocorrelation(x_samples[:,i]), color='k', alpha=0.3)
# mean
ax[i, j].plot(np.mean(np.array([autocorrelation(x_samples[:,i]) for i in range(0, len(x_samples.T))]), axis=0), color='r', label = 'mean')
# ax[i, j].set_xlim(0, len(x_samples))
ax[i, j].set_ylabel('x autocorrelation')
ax[i, j].legend(loc='upper right')

# autocorrelation for y
# all chains
for i in range(0, len(y_samples.T)):
    ax[1].plot(autocorrelation(y_samples[:,i]), color='k', alpha=0.3)
# mean
ax[1].plot(np.mean(np.array([autocorrelation(y_samples[:,i]) for i in range(0, len(y_samples.T))]), axis=0), color='r', label = 'mean')
# ax[1].set_xlim(0, len(y_samples))
ax[1].set_ylabel('y autocorrelation')
ax[1].legend(loc='upper right')

ax[1].set_xlabel('step number')
# Out:
# Text(0.5, 0, 'step number')

# %%
f = np.zeros(x_samples[:50, :].shape[1])

for x in x_samples[:50, :]:
    f += autocorrelation(x)

f /= len(x_samples[:50, :])    
taus = 2 * np.cumsum(f) - 1.0

m = np.arange(len(taus)) < 5.0 * taus
if np.any(m):
    print(np.argmin(m))
# print(len(taus) - 1)
# Out:
# 8

# %% [markdown]
# Defining functions to compute the autocorrelation time $\tau$, taken from the `emcee` docs:

# %%
# Automated windowing procedure following Sokal (1989)
def auto_window(taus, c):
    m = np.arange(len(taus)) < c * taus
    if np.any(m):
        return np.argmin(m)
    return len(taus) - 1

def autocorr_new(x, c=5.0):
    # empty list of walkers to average over
    f = np.zeros(len(x.T))
    # compute autocorrelation for each chain, then add all the autocorrelations together
    for xx in x:
        f += autocorrelation(xx)
    f /= len(x)
    
    # try this?
#     tau = 2 * np.sum(f) - 1.0
#     return tau
    
    # ORIGINAL
    
    # what?
    taus = 2.0 * np.cumsum(f) - 1.0
    window = auto_window(taus, c)
    return taus[window]

    # return np.min(taus)

# %% [markdown]
# Computing autocorrelation times:

# %%
# Compute the estimators for a few different chain lengths
N = 50
# chain legnths
chain_sizes = (10 ** np.linspace(1, 6, N)).astype(np.int64)

x_autocorrs = np.zeros(len(chain_sizes))
y_autocorrs = np.zeros(len(chain_sizes))

for i, n in enumerate(chain_sizes):
    x_autocorrs[i] = autocorr_new(x_samples[:n, :])
    y_autocorrs[i] = autocorr_new(y_samples[:n, :])

# %% [markdown]
# Plotting the autocorrelation times for $x$ and $y$ for different chain lengths:

# %%
plt.figure(figsize = (10, 7))
# plot the autocorrelations
plt.plot(chain_sizes, x_autocorrs, '-o', label = 'x')
plt.plot(chain_sizes, y_autocorrs, '-o', label = 'y')
# set xscale log
plt.xscale('log')# , plt.yscale('log')
# legend
plt.legend(loc = 'lower right')

# %%
raw_samples = sampler.get_chain()[200:]

emcee.autocorr.integrated_time(raw_samples)
# Out:
# array([48.0897219 , 44.70225179])

# %%
Ntimes = 20

integrated_times = np.zeros((Ntimes, 2))
chain_lengths = np.linspace(int(1e4), int(1e6), Ntimes)

for i, time in enumerate(chain_lengths):
    integrated_times[i] = emcee.autocorr.integrated_time(raw_samples[:int(time)])

# %%
plt.figure(figsize = (12, 8))
plt.plot(chain_lengths, integrated_times[:,0] , 'o-', label = 'x')
plt.plot(chain_lengths, integrated_times[:,1] , 'o-', label = 'y')
# plt.plot(chain_lengths, chain_lengths / 50.0)
plt.legend()
plt.xlabel('chain length'), plt.ylabel('integrated time')
plt.savefig('chain_lengths.png', fmt='png')
